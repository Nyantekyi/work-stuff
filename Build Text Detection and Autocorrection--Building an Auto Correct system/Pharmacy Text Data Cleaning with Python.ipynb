# %%
import pandas as pd
import numpy as np
import re
import string
from collections import Counter
import sidetable

# %%
df=pd.read_excel('F:/this.xlsx')

# %%
 class spellchecker(object):
        def __init__(self, filename):
            with open(filename, "r",encoding='utf-8') as file:
                lines =file.readlines()
                words=[]

                for line in lines:
                    words += re.findall(r'[^\n]+', line.lower(),re.M)
                    words += re.findall(r'\w+', line.lower())
            self.vocabs= set(words)
            self.words_counts= Counter(words)
            self.total_word_count=float(sum(self.words_counts.values()))
            self.word_probas= {word: self.words_counts[word]/self.total_word_count for word in self.vocabs}
        def _level_1_edits(self,word):
            letters=string.ascii_lowercase
            splits=[(word[:i],word[i:]) for i in range(len(word) +1)]
            delete=[l + r[1:] for l,r in splits if r]
            swap=[l + r[1] +r[0]+r[2:] for l,r in splits if len(r)>1]
            replace=[l + c +r[1:] for l,r in splits if r for c in letters]
            insert=[l + c+ r for l,r in splits for c in letters]
            return set(delete+replace+swap+insert)
        def _level_2_edits(self,word):
            return set(e2 for e1 in self._level_1_edits(word) for e2 in self._level_1_edits(e1))
        def _level_3_edits(self,word):
            return set(e3 for e2 in self._level_2_edits(word) for e3 in self._level_2_edits(e2))
        def _level_4_edits(self,word):
            return set(e4 for e3 in self._level_3_edits(word) for e4 in self._level_3_edits(e3))
        def _level_5_edits(self,word):
            return set(e5 for e4 in self._level_4_edits(word) for e5 in self._level_4_edits(e4))
        def _level_6_edits(self,word):
            return set(e6 for e5 in self._level_5_edits(word) for e6 in self._level_5_edits(e5))
        
        def check(self,word):
            candidate= self._level_1_edits(word) or self._level_2_edits(word) or self._level_3_edits(word)or self._level_4_edits(word) or self._level_5_edits(word) or self._level_6_edits(word) or[word] 
            valid_candidate= [w for w in candidate if w in self.vocabs]
            #print(self.words)
            return sorted([(c,self.word_probas[c]) for c in valid_candidate],key=lambda tup:tup[1],reverse=True)
        #def check
checker=spellchecker('./New Text Document (2).txt')

# %%
 def read_corpus(filename):
    with open(filename, "r",encoding='utf-8') as file:
        lines =file.readlines()
        words=[]

        for line in lines:
            words += re.findall(r'[^\n]+', line.lower(),re.M)
            words += re.findall(r'\w+', line.lower())
    return words

# %%
words=read_corpus("./New Text Document.txt")

# %%
words
# Out:
# ["(ats) anti tetanus injection 10's",
#  'ats',
#  'anti',
#  'tetanus',
#  'injection',
#  '10',
#  's',
#  '1st aid  kneee support',
#  '1st',
#  'aid',
#  'kneee',
#  'support',
#  '1st aid digital thermometer',
#  '1st',
#  'aid',
#  'digital',
#  'thermometer',
#  '1st aid hand and wrist support',
#  '1st',
#  'aid',
#  'hand',
#  'and',
#  'wrist',
#  'support',
#  '3cp anticeptic liquid 100ml',
#  '3cp',
#  'anticeptic',
#  'liquid',
#  '100ml',
#  '3cp antiseptic liquid 200ml',
#  '3cp',
#  'antiseptic',
#  'liquid',
#  '200ml',
#  'abc  teething mixture',
#  'abc',
#  'teething',
#  'mixture',
#  'abc cetirizine syr 100ml',
#  'abc',
#  'cetirizine',
#  'syr',
#  '100ml',
#  'abc chlorpheniramine syr 100ml',
#  'abc',
#  'chlorpheniramine',
#  'syr',
#  '100ml',
#  'abc cold syrup',
#  'abc',
#  'cold',
#  'syrup',
#  'abc ibuprofen syr 100ml',
#  'abc',
#  'ibuprofen',
#  'syr',
#  '100ml',
#  'abc ibuprofen syrup 100ml',
#  'abc',
#  'ibuprofen',
#  'syrup',
#  '100ml',
# ...

# %%
for k in df['Mallam']:
    print(k)
# Out:
# Actifed tab 60mg- 5
# Atwood’s bitters - 5
# Aldomet 500mg- 2
# Aerius 5mg tab- 1
# Aproxt eye drop- 1
# Actifed tab 12’s-5
# Alka seltzer-1
# Apflu syr-5
# Atenolol 50mg (Teva)- 5
# Atenolol 50mg(ECL)- 2
# Aciclovir eye ointment - 1
# Amoxycillin 500mg 21’s(UK)-3
# Amurox susp-3
# ABC vitamin C syr-5
# Anafranil 25mg-1
# Ascoryl plus-7
# Ashford executive toothbrush-12
# Antasil tab- 1
# Bells Olive oil-2
# Basekid syr 200ml- 3
# Bells Vitamin C-24
# Benadryl tab-2
# Benadryl syr-2
# Benylin paediatric-5
# Benylin original- 5
# Butter cup cough syrup 200ml -2
# Bendro 2.5mg(actavis)-5
# Bendro (Accord)2.5mg- 5(no other brand)
# Biopentin 30’s- 2
# Biotin Cap 5000mcg-1
# Cathether size 18, 20, 22 - 2 each
# Clindamycin 1% cream- 3
# Clotri-denk cream-4
# Colgate kids toothpaste-5
# Canula Blue - 5
# Calpol nasal spray- 5
# Clavulin susp 228mg & 457mg- 2 each
# Congestyl syrup- 10
# Combantrin -20
# Calorad caps-1
# Coldrilif Syrup - 5
# Citro C- 3
# ...

# %%
df.loc[df['Mallam'].str.contains('Actifed tab', case=False), 'Cleaned'] = 'Actifed Tab bitters'

# %%
df.loc[df['Mallam'].str.contains('Actifed tab', case=False), 'Cleaned'] = 'Actifed Tab bitters'
df.loc[df['Mallam'].str.contains('Atwood', case=False), 'Cleaned'] = "Atwood's bitters"
df.loc[df['Mallam'].str.contains('Aldomet 500', case=False), 'Cleaned'] = 'Aldomet 500mg'
df.loc[df['Mallam'].str.contains('Aldomet 250', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'
df.loc[df['Mallam'].str.contains('Aa', case=False), 'Cleaned'] = 'Aldomet 250mg'

# %%
df.loc[df['Mallam'].str.contains('[0-9]', case=False, regex=True), 'LOl'] = df

# %%
df.loc[df['Mallam'].str.contains('[0-9]'),'lol']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lol'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a09b5f5a5832> in <module>
# ...

# %%
drug=[('',''),]
